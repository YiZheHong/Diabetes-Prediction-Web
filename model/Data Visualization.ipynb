# %%
import pandas as pd

# %% [markdown]
# # Dataset Basic Info

# %%
df = pd.read_csv('diabetes_prediction_dataset.csv')
rows , col =  df.shape
print(f"Number of Rows : {rows} \nNumber of Columns : {col}")
# Out:
# Number of Rows : 100000
# Number of Columns : 9

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# # Data Preprocessing|

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Separate features and target
X = df.drop('diabetes', axis=1)
y = df['diabetes']

# Define categorical and numerical columns
categorical_cols = [cname for cname in X.columns if X[cname].dtype == "object"]
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)],
    remainder='drop')

# Fit the preprocessor to obtain transformed column names
X_preprocessed = preprocessor.fit_transform(X)
column_names = (numerical_cols + 
                list(preprocessor.named_transformers_['cat'].named_steps['onehot']
                     .get_feature_names_out(categorical_cols)))

# %% [markdown]
# # Class Imbalance

# %%
from sklearn.utils import resample

# Re-create DataFrame with new column names for easier manipulation
X_preprocessed_df = pd.DataFrame(X_preprocessed, columns=column_names)

# Add the target variable back to the dataframe
X_preprocessed_df['diabetes'] = y

# Separate majority and minority classes
df_majority = X_preprocessed_df[X_preprocessed_df.diabetes==0]
df_minority = X_preprocessed_df[X_preprocessed_df.diabetes==1]

# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                   replace=False,    # sample without replacement
                                   n_samples=8500,  # to match minority class
                                   random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# Display new class counts
print(df_downsampled.diabetes.value_counts())

# Removing the target variable from features dataset for selection
X_res = df_downsampled.drop('diabetes', axis=1)
y_res = df_downsampled['diabetes']
# Out:
# diabetes
# 0    8500
# 1    8500
# Name: count, dtype: int64

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Apply SelectKBest class to extract top k best features
bestfeatures = SelectKBest(score_func=f_classif, k=4)
bestfeatures.fit(X_res, y_res)

# Get the boolean mask of the selected features
mask = bestfeatures.get_support()  # list of booleans
selected_features = []  # The list of your K best features

for bool, feature in zip(mask, X_res.columns):
    if bool:
        selected_features.append(feature)

print("Selected features:", selected_features)
# Out:
# Selected features: ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']

# %% [markdown]
# # Dataset Split

# %%
from sklearn.model_selection import train_test_split

# Assuming 'selected_features' is the list of the names of the selected features
# Refine X_res to only include selected features
X_final = X_res[selected_features]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_final, y_res, test_size=0.2, random_state=42, stratify=y_res)

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Initialize the Support Vector Classifier
model = SVC(kernel='linear', C=1.0, random_state=42)  

# Train the model
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predict on the testing data
y_pred = model.predict(X_test)

# Print the classification report and confusion matrix
# print("Classification Report:\n", classification_report(y_test, y_pred))
# print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.8785294117647059

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Initialize the RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=100,  # Number of trees
                                random_state=42,   # Random state for reproducibility
                                max_features=4, # Number of features to consider at every split
                                max_depth=None,    # Maximum number of levels in tree
                                min_samples_split=2, # Minimum number of samples required to split a node
                                min_samples_leaf=1) # Minimum number of samples required at each leaf node
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=4, random_state=42)

# %%
# Predictions
y_pred = rf_clf.predict(X_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2%}")
# print("Classification Report:")
# print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 88.88%

# %%
from sklearn.neural_network import MLPClassifier
nn_clf = MLPClassifier(hidden_layer_sizes=(100,),  # One hidden layer with 100 neurons
                       activation='relu',         # Activation function for the neurons
                       solver='adam',             # Solver for weight optimization
                       max_iter=300,              # Maximum number of iterations
                       random_state=42,           # Random state for reproducibility
                       verbose=True)              # Print progress messages to stdout
nn_clf.fit(X_train, y_train)
y_pred = nn_clf.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Iteration 1, loss = 0.53162018
# Iteration 2, loss = 0.32610707
# Iteration 3, loss = 0.27176704
# Iteration 4, loss = 0.25653328
# Iteration 5, loss = 0.25129625
# Iteration 6, loss = 0.24837691
# Iteration 7, loss = 0.24590758
# Iteration 8, loss = 0.24394162
# Iteration 9, loss = 0.24174729
# Iteration 10, loss = 0.23954097
# Iteration 11, loss = 0.23741508
# Iteration 12, loss = 0.23509714
# Iteration 13, loss = 0.23308127
# Iteration 14, loss = 0.23084170
# Iteration 15, loss = 0.22860683
# Iteration 16, loss = 0.22652007
# Iteration 17, loss = 0.22482899
# Iteration 18, loss = 0.22288194
# Iteration 19, loss = 0.22117262
# Iteration 20, loss = 0.21928932
# Iteration 21, loss = 0.21780186
# Iteration 22, loss = 0.21610014
# Iteration 23, loss = 0.21436828
# Iteration 24, loss = 0.21315971
# Iteration 25, loss = 0.21170381
# Iteration 26, loss = 0.21038940
# Iteration 27, loss = 0.20918615
# Iteration 28, loss = 0.20821246
# Iteration 29, loss = 0.20715463
# Iteration 30, loss = 0.20623894
# Iteration 31, loss = 0.20519994
# Iteration 32, loss = 0.20435802
# Iteration 33, loss = 0.20364985
# Iteration 34, loss = 0.20295805
# Iteration 35, loss = 0.20231904
# Iteration 36, loss = 0.20177034
# Iteration 37, loss = 0.20100605
# Iteration 38, loss = 0.20042983
# Iteration 39, loss = 0.19988051
# Iteration 40, loss = 0.19942159
# Iteration 41, loss = 0.19892661
# Iteration 42, loss = 0.19860879
# Iteration 43, loss = 0.19802526
# Iteration 44, loss = 0.19773032
# Iteration 45, loss = 0.19717029
# Iteration 46, loss = 0.19693223
# Iteration 47, loss = 0.19647854
# Iteration 48, loss = 0.19619601
# Iteration 49, loss = 0.19588533
# Iteration 50, loss = 0.19557599
# Iteration 51, loss = 0.19532341
# Iteration 52, loss = 0.19478075
# Iteration 53, loss = 0.19468681
# Iteration 54, loss = 0.19446840
# Iteration 55, loss = 0.19429990
# Iteration 56, loss = 0.19406098
# Iteration 57, loss = 0.19375384
# Iteration 58, loss = 0.19353556
# Iteration 59, loss = 0.19326750
# Iteration 60, loss = 0.19326099
# Iteration 61, loss = 0.19292414
# Iteration 62, loss = 0.19258374
# Iteration 63, loss = 0.19262623
# Iteration 64, loss = 0.19229152
# Iteration 65, loss = 0.19214642
# Iteration 66, loss = 0.19209518
# Iteration 67, loss = 0.19189761
# Iteration 68, loss = 0.19171158
# Iteration 69, loss = 0.19150720
# Iteration 70, loss = 0.19138596
# Iteration 71, loss = 0.19129159
# Iteration 72, loss = 0.19118241
# Iteration 73, loss = 0.19111763
# Iteration 74, loss = 0.19107114
# Iteration 75, loss = 0.19073848
# Iteration 76, loss = 0.19092749
# Iteration 77, loss = 0.19100909
# Iteration 78, loss = 0.19032931
# Iteration 79, loss = 0.19036954
# Iteration 80, loss = 0.19031197
# Iteration 81, loss = 0.19015803
# Iteration 82, loss = 0.19012716
# Iteration 83, loss = 0.18979497
# Iteration 84, loss = 0.18976729
# Iteration 85, loss = 0.18987683
# Iteration 86, loss = 0.18967617
# Iteration 87, loss = 0.18957579
# Iteration 88, loss = 0.18956063
# Iteration 89, loss = 0.18958503
# Iteration 90, loss = 0.18947230
# Iteration 91, loss = 0.18933847
# Iteration 92, loss = 0.18930122
# Iteration 93, loss = 0.18933495
# Iteration 94, loss = 0.18900554
# Iteration 95, loss = 0.18900858
# Iteration 96, loss = 0.18896052
# Iteration 97, loss = 0.18905961
# Iteration 98, loss = 0.18898903
# Iteration 99, loss = 0.18878346
# Iteration 100, loss = 0.18892052
# Iteration 101, loss = 0.18872872
# Iteration 102, loss = 0.18859389
# Iteration 103, loss = 0.18874080
# Iteration 104, loss = 0.18851537
# Iteration 105, loss = 0.18843100
# Iteration 106, loss = 0.18835909
# Iteration 107, loss = 0.18846706
# Iteration 108, loss = 0.18861958
# Iteration 109, loss = 0.18838229
# Iteration 110, loss = 0.18824533
# Iteration 111, loss = 0.18826219
# Iteration 112, loss = 0.18822080
# Iteration 113, loss = 0.18807649
# Iteration 114, loss = 0.18819197
# Iteration 115, loss = 0.18793745
# Iteration 116, loss = 0.18825005
# Iteration 117, loss = 0.18804200
# Iteration 118, loss = 0.18813315
# Iteration 119, loss = 0.18810563
# Iteration 120, loss = 0.18780660
# Iteration 121, loss = 0.18780489
# Iteration 122, loss = 0.18772724
# Iteration 123, loss = 0.18796724
# Iteration 124, loss = 0.18746847
# Iteration 125, loss = 0.18787433
# Iteration 126, loss = 0.18757486
# Iteration 127, loss = 0.18766271
# Iteration 128, loss = 0.18766649
# Iteration 129, loss = 0.18759592
# Iteration 130, loss = 0.18743875
# Iteration 131, loss = 0.18742650
# Iteration 132, loss = 0.18739098
# Iteration 133, loss = 0.18742396
# Iteration 134, loss = 0.18767330
# Iteration 135, loss = 0.18740093
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy: 89.82%

# %%
# Out:
# Accuracy: 89.82%
